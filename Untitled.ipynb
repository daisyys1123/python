# %%
# 单行注释

# %%
'''
多行注释
'''
# Out:
# '\n多行注释\n'

# %%
print(7/3)
# Out:
# 2.3333333333333335

# %%
print(7//3)
# Out:
# 2

# %%
print(7%3)
# Out:
# 1

# %%
type(True)
# Out:
# bool

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
help(bin)
# Out:
# Help on built-in function bin in module builtins:
#
# bin(number, /)
#     Return the binary representation of an integer.
#
#     >>> bin(2796202)
#     '0b1010101010101010101010'

# %%
help(~)
# Out:
#   File "<ipython-input-13-2a4ba1e3ecdb>", line 1
#     help(~)
#           ^
# SyntaxError: invalid syntax

# %%
a = 1031
print(a, type(a))
# Out:
# 1031 <class 'int'>

# %%
print(bin(100))
# Out:
# 0b1100100

# %%
print(bin(16))
# Out:
# 0b10000

# %%
help(getcontext)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-74db83219e10> in <module>
# ----> 1 help(getcontext)
#
# NameError: name 'getcontext' is not defined

# %%
a=Decimal(1)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-09c8c546e709> in <module>
# ----> 1 a=Decimal(1)
#       2 print(a)
#
# NameError: name 'Decimal' is not defined
